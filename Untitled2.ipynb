# %% [markdown]
# <a href="https://colab.research.google.com/github/Farhaan427/2311cs020427-Sigma-assignments/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
iris_data=sns.load_dataset('iris')
df=sns.load_dataset('taxis')

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_width'])
plt.show()

# %%
sns.scatterplot(x=iris_data['sepal_length'],y=iris_data['petal_length'],hue=iris_data['species'],palette=['r','g','y'])
plt.show()

# %%
sns.scatterplot(x=df['payment'],y=df['total'],palette=['r','g']) # Changed df1 to df
plt.show()

# %%
sns.stripplot(x=df['payment'],y=df['tip'],palette=['r','g'])
plt.show()

# %%
sns.stripplot(x=df['payment'],y=df['tip'],palette=['r','g'])
# Out:
# <Axes: xlabel='payment', ylabel='tip'>

# %%
sns.lineplot(x=['total'],y=['fare'],hue=['payment'],palette=['red','orange'])
plt.show()

# %%
df[(df['payment']=='cash') & (df['tip']>0)]
# Out:
# Empty DataFrame
# Columns: [pickup, dropoff, passengers, distance, fare, tip, tolls, total, color, payment, pickup_zone, dropoff_zone, pickup_borough, dropoff_borough]
# Index: []

# %%
sns.lineplot(x=df['tip'],y=df['fare'],hue=df['payment'],palette=['red','orange'])
plt.show()

# %%
df[['payment','color']].value_counts()
# Out:
# payment      color
# credit card  yellow    4000
# cash         yellow    1412
# credit card  green      577
# cash         green      400
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# yellow    5451
# green      982
# Name: count, dtype: int64

# %%
df['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
sns.countplot(x=df['payment'],hue=df['color'],palette=['red','orange'])
plt.show()
